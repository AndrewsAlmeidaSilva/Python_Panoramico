# %%
from selenium                           import webdriver
from webdriver_manager.chrome           import ChromeDriverManager
from selenium.webdriver.chrome.service  import Service
from bs4                                import BeautifulSoup
from selenium.webdriver.chrome.options  import Options
from selenium.webdriver.common.by       import By
from time                               import sleep
import pandas                           as pd


#Definição da Cidade-------------------------------------

cidade = 'Colombo'

with open(f'bairros{cidade}.txt','r', encoding = 'utf-8') as arquivo:
    bairros = arquivo.readlines()

print(bairros)


#Abrindo navegador---------------------------------------------------------------------------------------

servico = Service(ChromeDriverManager().install())

options = Options()
options.add_argument('--headless')
options.add_argument("window-size= 800,800")
options.add_argument('service=servico')

navegador = webdriver.Chrome(options=options)



def pesquisar(bairro, cidade):
    navegador.get("https://www.google.com.br/maps/")
    pesquisa = navegador.find_element(By.TAG_NAME, "input")
    pesquisa.send_keys(f'escolas em {cidade} {bairro}')
    pesquisa.submit()
    
    sleep(10)

#MONTANDO AS LISTAS------------------------------------------------------------------------------------------
    
lista_nomeleads=[]
lista_sitemaps =[]
lista_nTefone  =[]
lista_nWhats   =[]
lista_endereco =[]
lista_site     =[]
lista_ativos   =[]
lista_bairro   =[]
lista_pesquisa =[]    
    
    
for bairro in bairros:
    
    pesquisar(bairro,cidade)
    
    page_content = navegador.page_source

    site = BeautifulSoup(page_content, 'html.parser')
    a = 0
    
    
    lista_pesquisa = []
    #ENCONTRANDO LEADS COM MAPS---------------------------------------------------------------------------------
    
    
    anuncios = site.findAll('div', attrs={'class': 'Nv2PK tH5CWc THOPZb'})
    
    for anuncio in anuncios:
        nome_comercio = anuncio.find('a', attrs={'class': 'hfpxzc'})['aria-label']
        site_ref = anuncio.find('a', attrs={'class': 'hfpxzc'})['href']
        a = a + 1
        
        lista_pesquisa.append(site_ref)
        #print(nome_comercio)
        #print(site_ref)
#        print()
    print(a)
    
    for enderecos in lista_pesquisa:
        navegador.get(f'{enderecos}')
        
        page_content = navegador.page_source
    
        site = BeautifulSoup(page_content, 'html.parser')
        sleep(5)
        
        nome_comerciall = site.find('h1', attrs={'class':'DUwDvf fontHeadlineLarge'})
    
        if nome_comerciall != None:
            nome_comercial = nome_comerciall.find('span').text
            print('nome comercial:',nome_comercial)
        else:
            nome_comercial = None
        
        dados = site.findAll('div', attrs={'class': 'RcCsl fVHpi w4vB1d NOE9ve M0S7ae AG25L'})
    
        
    
        local  = site.find('button', attrs={'data-tooltip': 'Copiar endereço'})
        
        if local != None:
            endereco_comercial = local.find('div', attrs={'class': 'Io6YTe fontBodyMedium'}).text
#            print('end: ',endereco_comercial)
        else:
            endereco_comercial = None
    

        whats    = site.find('a', attrs={'aria-label': 'whatsapp.com'})

        if whats != None:
            whats_comercio = whats['href']
#            print('whats: ',whats_comercio)   
        else:
            whats_comercio = None

    

        sitee    = site.find('a', attrs={'data-tooltip': 'Abrir website'})


        if sitee != None:
            site_comercio = sitee['href']
#            print('site:',site_comercio)
        else:
            site_comercio = None





        telefono = site.find('button', attrs={'data-tooltip': 'Copiar número de telefone'})

        if telefono != None:
            telefone_comercio  = telefono.find('div', attrs={'class':'Io6YTe fontBodyMedium'}).text

#            print('tel:',telefone_comercio)
        else:
            telefone_comercio = None


        ativos = 0

#        print('maps: ',enderecos)   

    
    
        lista_nomeleads.append(nome_comercial)
        lista_nTefone.append(telefone_comercio)
        lista_nWhats.append(whats_comercio)
        lista_site.append(site_comercio)
        lista_endereco.append(endereco_comercial)
        lista_sitemaps.append(enderecos)
        lista_ativos.append(ativos)
        lista_bairro.append(bairro)






        endereco_comercial = None
        nome_comercial     = None
        whats_comercio     = None
        site_comercio      = None
        telefone_comercio  = None
        endereco_maps      = None
        ativos             = None
        #print()
        #print()    
        #print()
#Montando Data Frame-----------------------------------------------------------------------------------------
df_leads = pd.DataFrame(data={'Leads(Parceiros)':lista_nomeleads,
                                   'Ativos (0/1)':lista_ativos,
                                   'Telefone':lista_nTefone,
                                   'Link Whatsapp':lista_nWhats,
                                   'Link Site':lista_site,
                                   'Endereço':lista_endereco,
                                   'Link Maps':lista_sitemaps,
                                    'Bairro': lista_bairro})

df_leads = df_leads.drop_duplicates(subset= 'Leads(Parceiros)')


#Criando Arquivo Excel com os Leads---------------------------------------------------------------------------

df_leads.to_excel(f'Leads_escolas{cidade}.xlsx', index = False)
# Out:
# ['Águas Fervidas\n', 'Área Rural de Colombo\n', 'Arruda\n', 'Atuba\n', 'Bacaetava\n', 'Boicininga\n', 'Butiatumirim\n', 'Campestre\n', 'Campo Pequeno\n', 'Canguiri\n', 'Capivari\n', 'Centro\n', 'Colônia Antônio Prado\n', 'Colônia Faria\n', 'Das Graças\n', 'Embu\n', 'Fátima\n', 'Gabirobal\n', 'Guaraituba\n', 'Guarani\n', 'Imbuial\n', 'Itajacuru\n', 'Maracanã\n', 'Mauá\n', 'Monza\n', 'Morro Grande\n', 'Osasco\n', 'Palmital\n', 'Paloma\n', 'Planta Boros\n', 'Poço Negro\n', 'Ribeirão das Onças\n', 'Rincão\n', 'Rio Verde\n', 'Roça Grande\n', 'Roseira\n', 'Santa Gema\n', 'Santa Terezinha\n', 'São Dimas\n', 'São Gabriel\n', 'São João\n', 'Sapopema\n', 'Serrinha\n', 'Uvaranal\n', 'Vila Guaraci']
# 5
# nome comercial: Colégio Bom Jesus Alphaville
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Santa Mônica
# nome comercial: Colégio Ágape
# nome comercial: Raio de Sol
# 4
# nome comercial: Rui Barbosa, C E-Ef M
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Rural Municipal Imbuial da Roseira
# nome comercial: Escola Santa Mônica
# 7
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Lar Escola Luciane Mary Paris
# nome comercial: Escola Estadual Tancredo de Almeida Neves
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Santa Mônica
# nome comercial: Escola Municipal Monteiro Lobato
# 4
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Santa Mônica
# nome comercial: Escola Municipal Monteiro Lobato
# 5
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Medianeira
# nome comercial: Colégio Estadual Zumbi dos Palmares
# nome comercial: Centro de Educação e Inclusão Social Betânia
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# 7
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Colégio Ágape
# nome comercial: Colégio Le Savant
# nome comercial: Rui Barbosa, C E-Ef M
# nome comercial: Centro de Educação e Inclusão Social Betânia
# 6
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Santa Mônica
# nome comercial: Altair Da Silva Leme, C E Prof-Ef M
# nome comercial: Escola Municipal Monteiro Lobato
# 8
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Centro de Educação e Inclusão Social Betânia
# nome comercial: Escola Estância Betânia
# nome comercial: Escola Santa Mônica
# nome comercial: Escola Municipal Nossa Senhora de Fátima
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Municipal Monteiro Lobato
# 7
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Escola Municipal John Kennedy
# nome comercial: Escola Municipal Presidente Castelo Branco
# nome comercial: Cinderela
# nome comercial: Escola Municipal Monteiro Lobato
# nome comercial: Cmei Canaa
# 5
# nome comercial: Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais
# nome comercial: Escola Trilhando o Futuro
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Santa Mônica
# nome comercial: Jardim Palmares
# 4
# nome comercial: Escola Trilhando o Futuro
# nome comercial: Colégio Estadual Zumbi dos Palmares
# nome comercial: Escola Rural Municipal Irmã Antonieta Farani
# nome comercial: Jardim Palmares
# 6
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Colégio Passionista Nossa Senhora do Rosário
# nome comercial: Escola Municipal Nossa Senhora de Fátima
# nome comercial: Centro de Educação e Inclusão Social Betânia
# 5
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Bom Jesus Alphaville
# nome comercial: Colégio Ágape
# nome comercial: Lar Escola Luciane Mary Paris
# 3
# nome comercial: Escola Trilhando o Futuro
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Colégio Ágape
# 0
# 4
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Pré Escola Espaço da Criança
# nome comercial: Escola Municipal Monteiro Lobato
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# 3
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Municipal Nossa Senhora de Fátima
# 5
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Medianeira
# nome comercial: Grupo Educacional Rosanna Cattalini
# nome comercial: Casa Do Luan
# nome comercial: Escola Municipal Vereador André Nadolny
# 5
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Municipal Padre Durval Secchi
# nome comercial: Colégio Le Savant
# nome comercial: Grupo Educacional Rosanna Cattalini
# 5
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Santa Mônica
# nome comercial: Escola Municipal Pedro Viriato Parigot de Souza - Caic
# 5
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Rural Municipal Imbuial da Roseira
# nome comercial: Colégio Estadual Zumbi dos Palmares
# nome comercial: Altair Da Silva Leme, C E Prof-Ef M
# 6
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Católica de Curitiba
# nome comercial: Colégio Ágape
# nome comercial: Colegio Dom Bosco Colombo
# nome comercial: ESCOLA EL SHADAY
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# 7
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Estadual Antônio Lacerda Braga
# nome comercial: Colégio Estadual Heráclito Fontoura Sobral Pinto
# nome comercial: Altair Da Silva Leme, C E Prof-Ef M
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Colégio Estadual Zumbi dos Palmares
# 6
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Estadual Zumbi dos Palmares
# nome comercial: Escola Furacão Mauá - Athletico Paranaense
# nome comercial: Centro de Educação e Inclusão Social Betânia
# nome comercial: Centro Municipal de Educação Infantil Girassol
# 4
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Colégio Estadual Helena Kolody
# nome comercial: Escola Santa Mônica
# 7
# nome comercial: Colégio Marista Santa Maria
# nome comercial: Colégio Ensitec
# nome comercial: Escola Iluminar - Educação Infantil e Ensino Fundamental
# nome comercial: Escola Santa Mônica
# nome comercial: Colégio Ágape
# nome comercial: Escola Municipal John Kennedy
# nome comercial: Joao Bosco, C E D-Ef M
# 5
# nome comercial: Colégio Marista Santa Maria
