# %%
from selenium                           import webdriver
from webdriver_manager.chrome           import ChromeDriverManager
from selenium.webdriver.chrome.service  import Service
from bs4                                import BeautifulSoup
from selenium.webdriver.chrome.options  import Options
from time                               import sleep
import pandas                           as pd

# %%
cidade = 'Pinhais'

with open(f'bairros{cidade}.txt','r', encoding = 'utf-8') as arquivo:
    bairros = arquivo.readlines()
print(bairros)
# Out:
# ['Vl Esplanada\n', 'Jd Atuba II\n', 'Vl M Antonieta\n', 'Estancia Pinhais\n', 'V Emiliano Perneta\n', 'Vl Amelia\n', 'Centro\n', 'Moradias Perdizes\n', 'Jd Alto Taruma\n', 'Vargem Grande\n', 'Jd Weisopolis\n', 'Jd Claudia\n', 'Cj Aquila\n', 'Jd Weissopolis\n', 'V Maria Antonieta\n', 'Vl Walde R Galvao\n', 'Vl Maria Antonieta\n', 'Vilaa M. Antonieta\n', 'Vl Irene Margarida\n', 'Vilaa Emiliano Perneta\n', 'Vl e Perneta\n', 'Jd Atuba I\n', 'Jd. Pinhais\n', 'Cj Atuba\n', 'V M Ant Santos\n', 'Emiliano Perneta\n', 'Estancia\n', 'Weissopolis\n', 'Vilaa Amelia\n', 'Jardim Weissopolis\n', 'Maria Antonieta\n', 'V Mariaantonieta\n', 'Walde Rosi Galvao\n', 'Jd Fenix\n', 'Atuba\n', 'Jardim Atuba I\n', 'Pinevelle\n', 'E Perneta\n', 'Pineville\n', 'Alto Taruma\n', 'Jd Atuba\n', 'Pq das Nascentes\n', 'Vilaa Esplanada\n', 'Núcleo Colonial d Pinhais']

# %%
print(bairros[2:4])
# Out:
# ['Vl M Antonieta\n', 'Estancia Pinhais\n']

# %%
from selenium                           import webdriver
from webdriver_manager.chrome           import ChromeDriverManager
from selenium.webdriver.chrome.service  import Service
from bs4                                import BeautifulSoup
from selenium.webdriver.chrome.options  import Options
from selenium.webdriver.common.by       import By
from time                               import sleep
import pandas                           as pd


#Definição da Cidade-------------------------------------

cidade = 'Pinhais'

with open(f'bairros{cidade}.txt','r', encoding = 'utf-8') as arquivo:
    bairros = arquivo.readlines()

print(bairros)


#Abrindo navegador---------------------------------------------------------------------------------------

servico = Service(ChromeDriverManager().install())

options = Options()
options.add_argument('--headless')
options.add_argument("window-size= 400,4000")
options.add_argument('service=servico')

navegador = webdriver.Chrome(options=options)



def pesquisar(bairro, cidade):
    navegador.get("https://www.google.com.br/maps/")
    pesquisa = navegador.find_element(By.TAG_NAME, "input")
    pesquisa.send_keys(f'escolas em {cidade} {bairro}')
    pesquisa.submit()
    
    sleep(10)

#MONTANDO AS LISTAS------------------------------------------------------------------------------------------
    
lista_nomeleads=[]
lista_sitemaps =[]
lista_nTefone  =[]
lista_nWhats   =[]
lista_endereco =[]
lista_site     =[]
lista_ativos   =[]
lista_bairro   =[]
lista_pesquisa =[]    
    
    
for bairro in bairros:
    
    pesquisar(bairro,cidade)
    
    page_content = navegador.page_source

    site = BeautifulSoup(page_content, 'html.parser')
    a = 0
    
    
    lista_pesquisa = []
    #ENCONTRANDO LEADS COM MAPS---------------------------------------------------------------------------------
    
    
    anuncios = site.findAll('div', attrs={'class': 'Nv2PK tH5CWc THOPZb'})
    
    for anuncio in anuncios:
        nome_comercio = anuncio.find('a', attrs={'class': 'hfpxzc'})['aria-label']
        site_ref = anuncio.find('a', attrs={'class': 'hfpxzc'})['href']
        a = a + 1
        
        lista_pesquisa.append(site_ref)
        #print(nome_comercio)
        #print(site_ref)
#        print()
    print(a)
    
    for enderecos in lista_pesquisa:
        navegador.get(f'{enderecos}')
        
        page_content = navegador.page_source
    
        site = BeautifulSoup(page_content, 'html.parser')
        sleep(5)
        
        nome_comerciall = site.find('h1', attrs={'class':'DUwDvf fontHeadlineLarge'})
    
        if nome_comerciall != None:
            nome_comercial = nome_comerciall.find('span').text
            print('nome comercial:',nome_comercial)
        else:
            nome_comercial = None
        
        dados = site.findAll('div', attrs={'class': 'RcCsl fVHpi w4vB1d NOE9ve M0S7ae AG25L'})
    
        
    
        local  = site.find('button', attrs={'data-tooltip': 'Copiar endereço'})
        
        if local != None:
            endereco_comercial = local.find('div', attrs={'class': 'Io6YTe fontBodyMedium'}).text
#            print('end: ',endereco_comercial)
        else:
            endereco_comercial = None
    

        whats    = site.find('a', attrs={'aria-label': 'whatsapp.com'})

        if whats != None:
            whats_comercio = whats['href']
#            print('whats: ',whats_comercio)   
        else:
            whats_comercio = None

    

        sitee    = site.find('a', attrs={'data-tooltip': 'Abrir website'})


        if sitee != None:
            site_comercio = sitee['href']
#            print('site:',site_comercio)
        else:
            site_comercio = None





        telefono = site.find('button', attrs={'data-tooltip': 'Copiar número de telefone'})

        if telefono != None:
            telefone_comercio  = telefono.find('div', attrs={'class':'Io6YTe fontBodyMedium'}).text

#            print('tel:',telefone_comercio)
        else:
            telefone_comercio = None


        ativos = 0

#        print('maps: ',enderecos)   

    
    
        lista_nomeleads.append(nome_comercial)
        lista_nTefone.append(telefone_comercio)
        lista_nWhats.append(whats_comercio)
        lista_site.append(site_comercio)
        lista_endereco.append(endereco_comercial)
        lista_sitemaps.append(enderecos)
        lista_ativos.append(ativos)
        lista_bairro.append(bairro)






        endereco_comercial = None
        nome_comercial     = None
        whats_comercio     = None
        site_comercio      = None
        telefone_comercio  = None
        endereco_maps      = None
        ativos             = None
        #print()
        #print()    
        #print()
#Montando Data Frame-----------------------------------------------------------------------------------------
df_leads = pd.DataFrame(data={'Leads(Parceiros)':lista_nomeleads,
                                   'Ativos (0/1)':lista_ativos,
                                   'Telefone':lista_nTefone,
                                   'Link Whatsapp':lista_nWhats,
                                   'Link Site':lista_site,
                                   'Endereço':lista_endereco,
                                   'Link Maps':lista_sitemaps,
                                    'Bairro': lista_bairro})

df_leads = df_leads.drop_duplicates(subset= 'Leads(Parceiros)')


#Criando Arquivo Excel com os Leads---------------------------------------------------------------------------

df_leads.to_excel(f'Leads_escolas{cidade}.xlsx', index = False)
# Out:
# 0
# 8
# nome comercial: Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais
# nome comercial: Escola Literal
# nome comercial: Escola Municipal Frei Egídio Carloto
# nome comercial: Colégio e Curso Acesso - Pinhais
# nome comercial: Escola Municipal Lírio Jacomel
# nome comercial: Colégio João Paulo II
# nome comercial: IEPI ESCOLA em Pinhais
# nome comercial: Colégio Destaque - ESCOLA em Pinhais
# 4
# nome comercial: Leocadia B Ramos, C E-Ef M Profis
# nome comercial: CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat
# nome comercial: Escola Municipal Guilherme Ceolin
# nome comercial: IEPI ESCOLA em Pinhais
# 11
# nome comercial: Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais
# nome comercial:
R. Bernardo Osinski, 206 - Pineville, Pinhais ...
# 319  R. Bernardo Osinski, 206 - Pineville, Pinhais ...
#
#                                              Link Maps                Bairro
# 7    https://www.google.com.br/maps/place/Col%C3%A9...         Jd Atuba II\n
# 16   https://www.google.com.br/maps/place/Col%C3%A9...    Estancia Pinhais\n
# 47   https://www.google.com.br/maps/place/Col%C3%A9...              Centro\n
# 59   https://www.google.com.br/maps/place/Col%C3%A9...   Moradias Perdizes\n
# 70   https://www.google.com.br/maps/place/Col%C3%A9...      Jd Alto Taruma\n
# 79   https://www.google.com.br/maps/place/Col%C3%A9...       Vargem Grande\n
# 90   https://www.google.com.br/maps/place/Col%C3%A9...       Jd Weisopolis\n
# 95   https://www.google.com.br/maps/place/Col%C3%A9...          Jd Claudia\n
# 104  https://www.google.com.br/maps/place/Col%C3%A9...           Cj Aquila\n
# 114  https://www.google.com.br/maps/place/Col%C3%A9...      Jd Weissopolis\n
# 166  https://www.google.com.br/maps/place/Col%C3%A9...          Jd Atuba I\n
# 169  https://www.google.com.br/maps/place/Col%C3%A9...         Jd. Pinhais\n
# 184  https://www.google.com.br/maps/place/Col%C3%A9...            Cj Atuba\n
# 189  https://www.google.com.br/maps/place/Col%C3%A9...      V M Ant Santos\n
# 203  https://www.google.com.br/maps/place/Col%C3%A9...            Estancia\n
# 211  https://www.google.com.br/maps/place/Col%C3%A9...         Weissopolis\n
# 220  https://www.google.com.br/maps/place/Col%C3%A9...        Vilaa Amelia\n
# 225  https://www.google.com.br/maps/place/Col%C3%A9...  Jardim Weissopolis\n
# 245  https://www.google.com.br/maps/place/Col%C3%A9...            Jd Fenix\n
# 260  https://www.google.com.br/maps/place/Col%C3%A9...               Atuba\n
# 269  https://www.google.com.br/maps/place/Col%C3%A9...      Jardim Atuba I\n
# 270  https://www.google.com.br/maps/place/Col%C3%A9...           Pinevelle\n
# 280  https://www.google.com.br/maps/place/Col%C3%A9...           E Perneta\n
# 291  https://www.google.com.br/maps/place/Col%C3%A9...           E Perneta\n
# 294  https://www.google.com.br/maps/place/Col%C3%A9...           Pineville\n
# 306  https://www.google.com.br/maps/place/Col%C3%A9...         Alto Taruma\n
# 319  https://www.google.com.br/maps/place/Col%C3%A9...     Vilaa Esplanada\n

# %%
lista_nomeleads
# Out:
# ['Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Literal',
#  'Escola Municipal Frei Egídio Carloto',
#  'Colégio e Curso Acesso - Pinhais',
#  'Escola Municipal Lírio Jacomel',
#  'Colégio João Paulo II',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Escola Municipal Guilherme Ceolin',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Trilhando o Futuro',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Estillo',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio João Paulo II',
#  'Colégio e Curso Acesso - Pinhais',
#  'The Woody House',
#  'Arnaldo F Busato,C E Dep-Ef M N Profis',
#  'Colégio Adventista Pinhais',
#  'Simone Piardi - Atendimento Educacional Especializado',
#  'Colégio Cidadão do Amanhã',
#  'Colégio Estillo',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio e Curso Acesso - Pinhais',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Centro Educacional Atuante - Polo Pinhais',
#  'Escola Municipal Frei Egídio Carloto',
#  'Colégio Adventista Pinhais',
#  'Colégio Suíço-Brasileiro de Curitiba',
#  'Colégio Cidadão do Amanhã',
#  'C E I Estrelinhas do Amanhã',
#  'Escola Municipal Lírio Jacomel',
#  'Instituto Federal do Paraná Campus Pinhais',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Escola Literal',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'Colégio Estillo',
#  'Escola Plural (Peter Pann)',
#  'CEEP Newton Freire Maia',
#  'Colégio Adventista Pinhais',
#  'Escola Trilhando o Futuro',
#  'Escola Plural (Peter Pann)',
#  'Arnaldo F Busato,C E Dep-Ef M N Profis',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Centro Educacional Atuante - Polo Pinhais',
#  'Colégio Estillo',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio João Paulo II',
#  'Escola Municipal Lírio Jacomel',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Trilhando o Futuro',
#  'Colégio Estillo',
#  'Colégio João Paulo II',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio e Curso Acesso - Pinhais',
#  'Escola Municipal Frei Egídio Carloto',
#  'Escola Plural (Peter Pann)',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio e Curso Acesso - Pinhais',
#  'Escola Municipal Lírio Jacomel',
#  'Escola Trilhando o Futuro',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio Estillo',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio João Paulo II',
#  'Colégio Suíço-Brasileiro de Curitiba',
#  'Colégio Cidadão do Amanhã',
#  'Escola Municipal Guilherme Ceolin',
#  'Instituto João Ferraz de Campos (IJFC)',
#  'Escola Furacão Pinhais - Oficial',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Academia De Musica Estrela',
#  'Construindo Sonhos',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Colégio Adventista Pinhais',
#  'Escola Plural (Peter Pann)',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Escola Municipal Lírio Jacomel',
#  'Secretaria Municipal de Educação',
#  None,
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Kinder Garden Lazer e Educação',
#  'CMEI - Centro Municipal de Educação Infantil Vinícius de Moraes',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio João Paulo II',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio e Curso Acesso - Pinhais',
#  'Escola Literal',
#  'Escola Municipal Lírio Jacomel',
#  'Escola Plural (Peter Pann)',
#  'Colégio Adventista Pinhais',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio e Curso Acesso - Pinhais',
#  'Colégio João Paulo II',
#  'Colégio Estillo',
#  'Escola Trilhando o Futuro',
#  'Colégio Estadual Semiramis de Barros Braga',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio João Paulo II',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Kinder Garden Lazer e Educação',
#  'Secretaria Municipal de Educação',
#  'Escola Municipal Lírio Jacomel',
#  'Escola Municipal Guilherme Ceolin',
#  'CMEI - Centro Municipal de Educação Infantil Vinícius de Moraes',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Escola Municipal Guilherme Ceolin',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Escola Municipal Guilherme Ceolin',
#  'Escola Municipal Lírio Jacomel',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio Cidadão do Amanhã',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Escola Municipal Guilherme Ceolin',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Estadual Semiramis de Barros Braga',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio Estillo',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio e Curso Acesso - Pinhais',
#  'IEPI ESCOLA em Pinhais',
#  'Centro Educacional Atuante - Polo Pinhais',
#  'Escola Trilhando o Futuro',
#  'Arnaldo F Busato,C E Dep-Ef M N Profis',
#  'Colégio Suíço-Brasileiro de Curitiba',
#  'Escola Plural (Peter Pann)',
#  'Simone Piardi - Atendimento Educacional Especializado',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio Estillo',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'IEPI ESCOLA em Pinhais',
#  'Escola Municipal Lírio Jacomel',
#  'Colégio Suíço-Brasileiro de Curitiba',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Escola Trilhando o Futuro',
#  'Arnaldo F Busato,C E Dep-Ef M N Profis',
#  'Escola Literal',
#  'Escola Municipal Frei Egídio Carloto',
#  'Colégio e Curso Acesso - Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Colégio João Paulo II',
#  'IEPI ESCOLA em Pinhais',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Escola Municipal Lírio Jacomel',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Literal',
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio João Paulo II',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio e Curso Acesso - Pinhais',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Municipal Frei Egídio Carloto',
#  'Escola Literal',
#  'Colégio Estillo',
#  'CMEI Atuba',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio João Paulo II',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Centro Educacional Atuante - Polo Pinhais',
#  'Escola Plural (Peter Pann)',
#  'Colégio Estillo',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio Adventista Pinhais',
#  'Escola Trilhando o Futuro',
#  'Colégio Estillo',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio e Curso Acesso - Pinhais',
#  'Escola Trilhando o Futuro',
#  'Colégio Adventista Pinhais',
#  'Centro Educacional Atuante - Polo Pinhais',
#  'Colégio João Paulo II',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Trilhando o Futuro',
#  'The Woody House',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Colégio Estillo',
#  'Colégio Cidadão do Amanhã',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio João Paulo II',
#  'CMEI - Centro Municipal de Educação Infantil Vinícius de Moraes',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Kinder Garden Lazer e Educação',
#  'Escola Municipal Lírio Jacomel',
#  'Secretaria Municipal de Educação',
#  'C E I Estrelinhas do Amanhã',
#  'Escola Municipal Lírio Jacomel',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Instituto Federal do Paraná Campus Pinhais',
#  'Colégio Estillo',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Escola Plural (Peter Pann)',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio João Paulo II',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Kinder Garden Lazer e Educação',
#  'Escola Municipal Guilherme Ceolin',
#  'Secretaria Municipal de Educação',
#  'CMEI - Centro Municipal de Educação Infantil Vinícius de Moraes',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Fantastica Ginástica RÍTMICA',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Estillo',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio João Paulo II',
#  'Colégio Estillo',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Escola Municipal Lírio Jacomel',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Shirley C T Machado, C E-Ef M',
#  'Escola Plural (Peter Pann)',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Escola Trilhando o Futuro',
#  'IEPI ESCOLA em Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Escola Literal',
#  'Escola Inspiração',
#  'Colégio João Paulo II',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Escola Municipal Frei Egídio Carloto',
#  'Escola Literal',
#  'Colégio Estillo',
#  'Colégio Adventista Pinhais',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'CMEI Atuba',
#  'IEPI ESCOLA em Pinhais',
#  'Escola Literal',
#  'Escola Municipal Frei Egídio Carloto',
#  'Colégio e Curso Acesso - Pinhais',
#  'Colégio Estillo',
#  'Walde Rosi Galvao, C E-Ef M',
#  'CMEI Atuba',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'CMEI - Centro Municipal de Educação Infantil Vó Margarida',
#  'São Joseense Escola Pinhais - Unidade Mendes',
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio João Paulo II',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'Escola Trilhando o Futuro',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio Estillo',
#  'IEPI ESCOLA em Pinhais',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Centro Educacional Atuante - Polo Pinhais',
#  'Colégio Suíço-Brasileiro de Curitiba',
#  'Walde Rosi Galvao, C E-Ef M',
#  'Arnaldo F Busato,C E Dep-Ef M N Profis',
#  'Escola Trilhando o Futuro',
#  'Colégio Adventista Pinhais',
#  'Colégio João Paulo II',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Inst Ed Pr Prof Erasmo Pilotto-Ef M N',
#  'Escola Literal',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'CMEI - Centro Municipal de Educação Infantil Vó Margarida',
#  'São Joseense Escola Pinhais - Unidade Mendes',
#  'Escola Municipal Guilherme Ceolin',
#  'Colégio João Paulo II',
#  'Fisk',
#  'Escola Furacão Pinhais - Oficial',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio Cidadão do Amanhã - Pinhais. Escola - Cidadão em Pinhais',
#  'Colégio e Curso Acesso - Pinhais',
#  'Escola Municipal Lírio Jacomel',
#  'Escola Literal',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Colégio Estillo',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'CEEP Newton Freire Maia',
#  'Escola Literal',
#  'Escola Municipal Frei Egídio Carloto',
#  'Escola Municipal Lírio Jacomel',
#  'Colégio e Curso Acesso - Pinhais',
#  'CMEI Atuba',
#  "Colégio Estadual Oscar Joseph D'Plácido e Silva - EFM",
#  'Colégio Cidadão do Amanhã',
#  'Leocadia B Ramos, C E-Ef M Profis',
#  'Colégio Estadual Semiramis de Barros Braga',
#  'Colégio Destaque - ESCOLA em Pinhais',
#  'Walde Rosi Galvao, C E-Ef M',
#  'IEPI ESCOLA em Pinhais',
#  'CMEI - Centro Municipal de Educação Infantil Marcelino Champagnat',
#  'Colégio Adventista Pinhais']

# %%
df_leads = df_leads.drop_duplicates(subset= 'Leads(Parceiros)')

df_leads.to_excel(f'Leads_escolas{cidade}.xlsx', index = False)

# %%
navegador.close()
